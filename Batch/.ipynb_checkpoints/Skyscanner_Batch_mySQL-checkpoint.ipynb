# %% [markdown]
# ### Batch mySQL to Spark (1)

# %%
import pandas as pd
from pyspark.sql import SparkSession

## Connect to MySQL (Airport)
dataframe_mysql_airport = sqlContext.read.format("jdbc").option("url", "jdbc:mysql://127.0.0.1 /skyscanner_batch")\
.option("driver", "com.mysql.jdbc.Driver").option("dbtable", "airports").option("user", "root")\
.option("password", "").load()

## Connect to MySQL (Cities)
dataframe_mysql_cities = sqlContext.read.format("jdbc").option("url", "jdbc:mysql://127.0.0.1 /skyscanner_batch")\
.option("driver", "com.mysql.jdbc.Driver").option("dbtable", "cities").option("user", "root")\
.option("password", "").load()

# %%
#Airport Table
AirportDF =  dataframe_mysql_airport.toPandas()
AirportJSON = AirportDF.to_json(orient="records")

#Cities Data
CitiesDF =  dataframe_mysql_cities.toPandas()
CitiesJSON = CitiesDF.to_json(orient="records")

# %% [markdown]
# ### Batch to Kafka Producer (Don't Need it)

# %%
# import kafka
# from kafka import KafkaProducer

# ## Connect to Producer
# producer = KafkaProducer(bootstrap_servers='localhost:9092')

# lines = [x.strip() for x in AirportDF]

# ## Send Airports table to Topic 'airports'
# for line in lines:
#     future = producer.send('airports', bytes(line, encoding= 'utf-8'))
#     producer.flush()

# %%
# lines2 = [n.strip() for n in CitiesDF]

# ## Send Cities table to Topic 'cities'
# for line2 in lines2:
#     future = producer.send('cities', bytes(line2, encoding= 'utf-8'))
#     producer.flush()

# %% [markdown]
# ### Elasticsearch Index Creation for SQL Data  (2)

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200/')
es.indices.create(index="airports_api", ignore=400)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-67dcd040fc82> in <module>
#       1 from elasticsearch import Elasticsearch
#       2
# ----> 3 es,es2 = Elasticsearch('http://localhost:9200/')
#       4 es.indices.create(index="airports_api", ignore=400)
#       5 es.indices.create(index="cities_api", ignore=400)
#
# TypeError: 'Elasticsearch' object is not iterable

# %%
es2 = Elasticsearch('http://localhost:9200/')
es2.indices.create(index="cities_api", ignore=400)
# Out:
# {'error': {'root_cause': [{'type': 'resource_already_exists_exception',
#     'reason': 'index [cities_api/760FkXplR_2xLGpau2kcAw] already exists',
#     'index_uuid': '760FkXplR_2xLGpau2kcAw',
#     'index': 'cities_api'}],
#   'type': 'resource_already_exists_exception',
#   'reason': 'index [cities_api/760FkXplR_2xLGpau2kcAw] already exists',
#   'index_uuid': '760FkXplR_2xLGpau2kcAw',
#   'index': 'cities_api'},
#  'status': 400}

# %% [markdown]
# ### Parse Data to Index in ES (3)

# %%
import json

for i, item in AirportDF.iterrows():
    es.index(index="airports_api", 
         doc_type = "json" , 
         body = {"IATA":item['IATA'],"Airport_Name":item['Airport_Name'],"City_ID":item['City_ID']})

# %%
for x, items in CitiesDF.iterrows():
    es2.index(index="cities_api", 
         doc_type = "json", 
         body = {"City_ID":items['City_ID'],"City_Name":items[' City_Name'],"Country_Name":items[' Country_Name'],"Country_Code":items[' Country_Code']})
# Out:
# City_ID                    1
#  City_Name             Assen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 0, dtype: object
# City_ID                    2
#  City_Name         Coevorden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 1, dtype: object
# City_ID                    3
#  City_Name             Emmen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 2, dtype: object
# City_ID                    4
#  City_Name         Hoogeveen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 3, dtype: object
# City_ID                    5
#  City_Name            Meppel
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 4, dtype: object
# City_ID                    6
#  City_Name            Almere
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 5, dtype: object
# City_ID                      7
#  City_Name       Biddinghuizen
#  Country_Name      Netherlands
#  Country_Code               NL
# Name: 6, dtype: object
# City_ID                    8
#  City_Name         Emmeloord
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 7, dtype: object
# City_ID                    9
#  City_Name          Lelystad
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 8, dtype: object
# City_ID                   10
#  City_Name         Bolsward
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 9, dtype: object
# City_ID                   11
#  City_Name            Dokkum
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 10, dtype: object
# City_ID                   12
#  City_Name         Franeker
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 11, dtype: object
# City_ID                   13
#  City_Name        Harlingen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 12, dtype: object
# City_ID                   14
#  City_Name       Hindeloopen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 13, dtype: object
# City_ID                   15
#  City_Name            IJlst
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 14, dtype: object
# City_ID                   16
#  City_Name        Leeuwarden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 15, dtype: object
# City_ID                   17
#  City_Name            Sloten
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 16, dtype: object
# City_ID                   18
#  City_Name             Sneek
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 17, dtype: object
# City_ID                   19
#  City_Name          Stavoren
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 18, dtype: object
# City_ID                   20
#  City_Name            Workum
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 19, dtype: object
# City_ID                   21
#  City_Name        Apeldoorn
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 20, dtype: object
# City_ID                   22
#  City_Name            Arnhem
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 21, dtype: object
# City_ID                   23
#  City_Name       Bredevoort
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 22, dtype: object
# City_ID                   24
#  City_Name             Buren
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 23, dtype: object
# City_ID                   25
#  City_Name         Culemborg
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 24, dtype: object
# City_ID                   26
#  City_Name            Dieren
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 25, dtype: object
# City_ID                   27
#  City_Name        Doetinchem
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 26, dtype: object
# City_ID                   28
#  City_Name               Ede
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 27, dtype: object
# City_ID                   29
#  City_Name           Enspijk
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 28, dtype: object
# City_ID                   30
#  City_Name             Gendt
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 29, dtype: object
# City_ID                   31
#  City_Name           Groenlo
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 30, dtype: object
# City_ID                   32
#  City_Name        Harderwijk
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 31, dtype: object
# City_ID                   33
#  City_Name            Hattem
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 32, dtype: object
# City_ID                   34
#  City_Name          Heukelum
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 33, dtype: object
# City_ID                   35
#  City_Name           Huissen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 34, dtype: object
# City_ID                   36
#  City_Name           Nijkerk
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 35, dtype: object
# City_ID                   37
#  City_Name         Nijmegen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 36, dtype: object
# City_ID                   38
#  City_Name              Tiel
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 37, dtype: object
# City_ID                   39
#  City_Name        Wageningen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 38, dtype: object
# City_ID                   40
#  City_Name           Wijchen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 39, dtype: object
# City_ID                   41
#  City_Name       Winterswijk
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 40, dtype: object
# City_ID                   42
#  City_Name        Zaltbommel
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 41, dtype: object
# City_ID                   43
#  City_Name          Zevenaar
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 42, dtype: object
# City_ID                   44
#  City_Name           Zutphen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 43, dtype: object
# City_ID                   45
#  City_Name        Appingedam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 44, dtype: object
# City_ID                   46
#  City_Name          Delfzijl
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 45, dtype: object
# City_ID                   47
#  City_Name         Groningen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 46, dtype: object
# City_ID                            48
#  City_Name       Hoogezand-Sappemeer
#  Country_Name             Netherlands
#  Country_Code                      NL
# Name: 47, dtype: object
# City_ID                   49
#  City_Name       Stadskanaal
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 48, dtype: object
# City_ID                   50
#  City_Name           Veendam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 49, dtype: object
# City_ID                   51
#  City_Name        Winschoten
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 50, dtype: object
# City_ID                   52
#  City_Name              Echt
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 51, dtype: object
# City_ID                   53
#  City_Name            Geleen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 52, dtype: object
# City_ID                   54
#  City_Name            Gennep
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 53, dtype: object
# City_ID                   55
#  City_Name          Heerlen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 54, dtype: object
# City_ID                   56
#  City_Name          Kerkrade
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 55, dtype: object
# City_ID                   57
#  City_Name            Kessel
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 56, dtype: object
# City_ID                   58
#  City_Name         Landgraaf
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 57, dtype: object
# City_ID                   59
#  City_Name        Maastricht
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 58, dtype: object
# City_ID                   60
#  City_Name          Montfort
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 59, dtype: object
# City_ID                   61
#  City_Name        Nieuwstadt
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 60, dtype: object
# City_ID                   62
#  City_Name         Roermond
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 61, dtype: object
# City_ID                     63
#  City_Name       Schin op Geul
#  Country_Name      Netherlands
#  Country_Code               NL
# Name: 62, dtype: object
# City_ID                   64
#  City_Name           Sittard
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 63, dtype: object
# City_ID                   65
#  City_Name             Stein
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 64, dtype: object
# City_ID                   66
#  City_Name          Susteren
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 65, dtype: object
# City_ID                   67
#  City_Name             Thorn
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 66, dtype: object
# City_ID                   68
#  City_Name        Valkenburg
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 67, dtype: object
# City_ID                   69
#  City_Name             Venlo
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 68, dtype: object
# City_ID                   70
#  City_Name             Weert
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 69, dtype: object
# City_ID                       71
#  City_Name       s-Hertogenbosch
#  Country_Name        Netherlands
#  Country_Code                 NL
# Name: 70, dtype: object
# City_ID                      72
#  City_Name       Bergen op Zoom
#  Country_Name       Netherlands
#  Country_Code                NL
# Name: 71, dtype: object
# City_ID                   73
#  City_Name            Boxtel
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 72, dtype: object
# City_ID                   74
#  City_Name            Breda
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 73, dtype: object
# City_ID                   75
#  City_Name        Eindhoven
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 74, dtype: object
# City_ID                        76
#  City_Name       Geertruidenberg
#  Country_Name         Netherlands
#  Country_Code                  NL
# Name: 75, dtype: object
# City_ID                   77
#  City_Name           Geldrop
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 76, dtype: object
# City_ID                   78
#  City_Name             Grave
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 77, dtype: object
# City_ID                   79
#  City_Name          Helmond
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 78, dtype: object
# City_ID                   80
#  City_Name           Heusden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 79, dtype: object
# City_ID                   81
#  City_Name          Klundert
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 80, dtype: object
# City_ID                   82
#  City_Name       Oosterhout
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 81, dtype: object
# City_ID                   83
#  City_Name               Oss
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 82, dtype: object
# City_ID                   84
#  City_Name        Ravenstein
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 83, dtype: object
# City_ID                   85
#  City_Name       Roosendaal
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 84, dtype: object
# City_ID                      86
#  City_Name       Sint-Oedenrode
#  Country_Name       Netherlands
#  Country_Code                NL
# Name: 85, dtype: object
# City_ID                   87
#  City_Name          Tilburg
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 86, dtype: object
# City_ID                     88
#  City_Name       Valkenswaard
#  Country_Name      Netherlands
#  Country_Code               NL
# Name: 87, dtype: object
# City_ID                   89
#  City_Name        Veldhoven
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 88, dtype: object
# City_ID                   90
#  City_Name          Waalwijk
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 89, dtype: object
# City_ID                   91
#  City_Name        Willemstad
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 90, dtype: object
# City_ID                   92
#  City_Name        Woudrichem
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 91, dtype: object
# City_ID                   93
#  City_Name           Alkmaar
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 92, dtype: object
# City_ID                   94
#  City_Name        Amstelveen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 93, dtype: object
# City_ID                   95
#  City_Name         Amsterdam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 94, dtype: object
# City_ID                   96
#  City_Name        Den Helder
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 95, dtype: object
# City_ID                   97
#  City_Name              Edam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 96, dtype: object
# City_ID                   98
#  City_Name         Enkhuizen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 97, dtype: object
# City_ID                   99
#  City_Name           Haarlem
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 98, dtype: object
# City_ID                    100
#  City_Name       Heerhugowaard
#  Country_Name      Netherlands
#  Country_Code               NL
# Name: 99, dtype: object
# City_ID                  101
#  City_Name         Hilversum
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 100, dtype: object
# City_ID                  102
#  City_Name         Hoofddorp
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 101, dtype: object
# City_ID                  103
#  City_Name             Hoorn
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 102, dtype: object
# City_ID                  104
#  City_Name             Laren
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 103, dtype: object
# City_ID                  105
#  City_Name         Medemblik
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 104, dtype: object
# City_ID                   106
#  City_Name       Monnickendam
#  Country_Name     Netherlands
#  Country_Code              NL
# Name: 105, dtype: object
# City_ID                  107
#  City_Name           Muiden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 106, dtype: object
# City_ID                  108
#  City_Name           Naarden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 107, dtype: object
# City_ID                  109
#  City_Name         Purmerend
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 108, dtype: object
# City_ID                  110
#  City_Name           Schagen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 109, dtype: object
# City_ID                  111
#  City_Name            Velsen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 110, dtype: object
# City_ID                  112
#  City_Name          Volendam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 111, dtype: object
# City_ID                  113
#  City_Name             Weesp
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 112, dtype: object
# City_ID                  114
#  City_Name          Zaanstad
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 113, dtype: object
# City_ID                  115
#  City_Name            Almelo
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 114, dtype: object
# City_ID                  116
#  City_Name          Blokzijl
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 115, dtype: object
# City_ID                  117
#  City_Name         Deventer
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 116, dtype: object
# City_ID                  118
#  City_Name         Enschede
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 117, dtype: object
# City_ID                  119
#  City_Name        Genemuiden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 118, dtype: object
# City_ID                  120
#  City_Name           Hasselt
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 119, dtype: object
# City_ID                  121
#  City_Name           Hengelo
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 120, dtype: object
# City_ID                  122
#  City_Name            Kampen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 121, dtype: object
# City_ID                  123
#  City_Name         Oldenzaal
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 122, dtype: object
# City_ID                  124
#  City_Name         Steenwijk
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 123, dtype: object
# City_ID                  125
#  City_Name        Vollenhove
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 124, dtype: object
# City_ID                  126
#  City_Name            Zwolle
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 125, dtype: object
# City_ID                          127
#  City_Name       Alphen aan den Rijn
#  Country_Name            Netherlands
#  Country_Code                     NL
# Name: 126, dtype: object
# City_ID                  128
#  City_Name             Delft
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 127, dtype: object
# City_ID                  129
#  City_Name         Dordrecht
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 128, dtype: object
# City_ID                  130
#  City_Name         Gorinchem
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 129, dtype: object
# City_ID                  131
#  City_Name             Gouda
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 130, dtype: object
# City_ID                  132
#  City_Name           Leerdam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 131, dtype: object
# City_ID                  133
#  City_Name            Leiden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 132, dtype: object
# City_ID                  134
#  City_Name         Rotterdam
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 133, dtype: object
# City_ID                  135
#  City_Name       Spijkenisse
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 134, dtype: object
# City_ID                  136
#  City_Name         The Hague
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 135, dtype: object
# City_ID                  137
#  City_Name        Zoetermeer
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 136, dtype: object
# City_ID                  138
#  City_Name        Amersfoort
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 137, dtype: object
# City_ID                  139
#  City_Name             Baarn
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 138, dtype: object
# City_ID                  140
#  City_Name        Bunschoten
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 139, dtype: object
# City_ID                  141
#  City_Name            Eemnes
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 140, dtype: object
# City_ID                  142
#  City_Name         Hagestein
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 141, dtype: object
# City_ID                  143
#  City_Name            Houten
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 142, dtype: object
# City_ID                  144
#  City_Name         Montfoort
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 143, dtype: object
# City_ID                  145
#  City_Name        Nieuwegein
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 144, dtype: object
# City_ID                  146
#  City_Name         Oudewater
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 145, dtype: object
# City_ID                  147
#  City_Name            Rhenen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 146, dtype: object
# City_ID                  148
#  City_Name           Utrecht
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 147, dtype: object
# City_ID                  149
#  City_Name        Veenendaal
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 148, dtype: object
# City_ID                  150
#  City_Name            Vianen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 149, dtype: object
# City_ID                         151
#  City_Name       Wijk bij Duurstede
#  Country_Name           Netherlands
#  Country_Code                    NL
# Name: 150, dtype: object
# City_ID                  152
#  City_Name           Woerden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 151, dtype: object
# City_ID                  153
#  City_Name       IJsselstein
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 152, dtype: object
# City_ID                  154
#  City_Name             Zeist
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 153, dtype: object
# City_ID                  155
#  City_Name        Arnemuiden
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 154, dtype: object
# City_ID                  156
#  City_Name              Goes
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 155, dtype: object
# City_ID                  157
#  City_Name             Hulst
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 156, dtype: object
# City_ID                  158
#  City_Name        Middelburg
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 157, dtype: object
# City_ID                  159
#  City_Name             Sluis
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 158, dtype: object
# City_ID                  160
#  City_Name         Terneuzen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 159, dtype: object
# City_ID                  161
#  City_Name             Veere
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 160, dtype: object
# City_ID                  162
#  City_Name        Vlissingen
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 161, dtype: object
# City_ID                  163
#  City_Name         Zierikzee
#  Country_Name    Netherlands
#  Country_Code             NL
# Name: 162, dtype: object

# %% [markdown]
# ### Pyspark do here????

# %%
from kafka import KafkaConsumer
import pandas

consumer = KafkaConsumer(bootstrap_servers='localhost:9092',
                                 auto_offset_reset='earliest',
                                 consumer_timeout_ms=1000)
consumer.subscribe(['crowdedness'])



crowdedness = [msg.value.decode('utf-8') for msg in consumer]
print(crowdedness)
# Out:
# ['', '', '', '', '[{"Flight_ID": "0", "Flight_NR": "1", "Departure_Date": "2252", "Departure_Time": "25-11-2018", "Departure_Airport_ID": "3:40:00 AM", "Arrival_Date": "EIN", "Arrival_Time": "25-11-2018", "Destination_Airport_ID": "5:30:00 AM", "Airline": "LEY", "Price": "Atlantic Airways", "Delay": "746", "Cancellation": "FALSE"}, {"Flight_ID": "1", "Flight_NR": "2", "Departure_Date": "3028", "Departure_Time": "28-11-2018", "Departure_Airport_ID": "4:00:00 AM", "Arrival_Date": "AMS", "Arrival_Time": "28-11-2018", "Destination_Airport_ID": "5:00:00 AM", "Airline": "RTM", "Price": "Atlantic Airways", "Delay": "497", "Cancellation": "FALSE"}, {"Flight_ID": "2", "Flight_NR": "3", "Departure_Date": "6200", "Departure_Time": "30-11-2018", "Departure_Airport_ID": "7:40:00 PM", "Arrival_Date": "ENS", "Arrival_Time": "30-11-2018", "Destination_Airport_ID": "8:30:00 PM", "Airline": "RTM", "Price": "Atlantic Airways", "Delay": "505", "Cancellation": "TRUE"}, {"Flight_ID": "3", "Flight_NR": "4", "Departure_Date": "5098", "Departure_Time": "23-11-2018", "Departure_Airport_ID": "11:20:00 AM", "Arrival_Date": "MST", "Arrival_Time": "23-11-2018", "Destination_Airport_ID": "12:20:00 PM", "Airline": "AMS", "Price": "Atlantic Airways", "Delay": "957", "Cancellation": "FALSE"}, {"Flight_ID": "4", "Flight_NR": "5", "Departure_Date": "7572", "Departure_Time": "27-11-2018", "Departure_Airport_ID": "7:50:00 AM", "Arrival_Date": "GRQ", "Arrival_Time": "27-11-2018", "Destination_Airport_ID": "8:10:00 AM", "Airline": "MST", "Price": "Atlantic Airways", "Delay": "377", "Cancellation": "FALSE"}, {"Flight_ID": "5", "Flight_NR": "6", "Departure_Date": "7856", "Departure_Time": "24-11-2018", "Departure_Airport_ID": "4:30:00 PM", "Arrival_Date": "MST", "Arrival_Time": "24-11-2018", "Destination_Airport_ID": "6:00:00 PM", "Airline": "MST", "Price": "Atlantic Airways", "Delay": "916", "Cancellation": "TRUE"}, {"Flight_ID": "6", "Flight_NR": "7", "Departure_Date": "3839", "Departure_Time": "24-11-2018", "Departure_Airport_ID": "2:00:00 PM", "Arrival_Date": "MST", "Arrival_Time": "24-11-2018", "Destination_Airport_ID": "5:10:00 PM", "Airline": "ENS", "Price": "Atlantic Airways", "Delay": "211", "Cancellation": "FALSE"}, {"Flight_ID": "7", "Flight_NR": "8", "Departure_Date": "5876", "Departure_Time": "29-11-2018", "Departure_Airport_ID": "10:20:00 AM", "Arrival_Date": "RTM", "Arrival_Time": "29-11-2018", "Destination_Airport_ID": "11:30:00 AM", "Airline": "ENS", "Price": "Atlantic Airways", "Delay": "690", "Cancellation": "TRUE"}, {"Flight_ID": "8", "Flight_NR": "9", "Departure_Date": "6754", "Departure_Time": "30-11-2018", "Departure_Airport_ID": "2:30:00 AM", "Arrival_Date": "AMS", "Arrival_Time": "30-11-2018", "Destination_Airport_ID": "4:10:00 AM", "Airline": "AMS", "Price": "Atlantic Airways", "Delay": "529", "Cancellation": "FALSE"}, {"Flight_ID": "9", "Flight_NR": "10", "Departure_Date": "4728", "Departure_Time": "24-11-2018", "Departure_Airport_ID": "9:50:00 AM", "Arrival_Date": "RTM", "Arrival_Time": "24-11-2018", "Destination_Airport_ID": "10:00:00 AM", "Airline": "RTM", "Price": "Atlantic Airways", "Delay": "643", "Cancellation": "FALSE"}, {"Flight_ID": "10", "Flight_NR": "11", "Departure_Date": "2830", "Departure_Time": "27-11-2018", "Departure_Airport_ID": "1:20:00 PM", "Arrival_Date": "LEY", "Arrival_Time": "27-11-2018", "Destination_Airport_ID": "2:00:00 PM", "Airline": "ENS", "Price": "Atlantic Airways", "Delay": "488", "Cancellation": "FALSE"}, {"Flight_ID": "11", "Flight_NR": "12", "Departure_Date": "1002", "Departure_Time": "24-11-2018", "Departure_Airport_ID": "5:30:00 PM", "Arrival_Date": "AMS", "Arrival_Time": "24-11-2018", "Destination_Airport_ID": "6:30:00 PM", "Airline": "LEY", "Price": "Atlantic Airways", "Delay": "527", "Cancellation": "FALSE"}, {"Flight_ID": "12", "Flight_NR": "13", "Departure_Date": "6645", "Departure_Time": "27-11-2018", "Departure_Airport_ID": "3:30:00 PM", "Arrival_Date": "GRQ", "Arrival_Time": "27-11-2018", "Desti ...
